# %% [markdown]
# **SuperHero's Dataset**

# %%
#Importing Libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('superheroes_nlp_dataset.csv')
score_cols = df.columns[df.columns.str.contains("_score")]
demo_cols = ['name','teams','creator','gender']
score_cols
powers_cols = df.columns[df.columns.str.contains("has")]
powers_cols
df['combine_score']=df[['intelligence_score','strength_score']].sum(axis=1)
df[['combine_score','intelligence_score','strength_score']]
filtered_column_names = [item for item in score_cols if item != 'overall_score']

filtered_column_names
# Out:
# ['intelligence_score',
#  'strength_score',
#  'speed_score',
#  'durability_score',
#  'power_score',
#  'combat_score']

# %%
df['combine_score']=df[filtered_column_names].sum(axis=1)
df['powers'] = df[powers_cols].sum(axis=1)

# %%
df[['overall_score']+['powers']+['combine_score']+demo_cols].sort_values(by=['overall_score','powers','combine_score'], ascending=False).head(20)
# Out:
#      overall_score  powers  combine_score                       name  \
# 1281             ∞    47.0            600          The Golden Master
# 526              ∞    44.0            600       Golden Master's Mech
# 174              ∞    42.0            565                Black Alice
# 482              ∞    40.0            600     First Spinjitzu Master
# 1337             ∞    34.0            600         True Form Oblivion
# 809              ∞    33.0            600            Living Tribunal
# 1272             ∞    33.0            550  The Beyonder (Earth-1298)
# 882              ∞    31.0            600          Michael Demiurgos
# 376              ∞    31.0            550       Death Of The Endless
# 1202             ∞    29.0            580           Spectre Oversoul
# 153              ∞    28.0            590                   Beyonder
# 803              ∞    27.0            600             Little Krishna
# 1290             ∞    27.0            600          The One Below All
# 845              ∞    21.0            600            Man Of Miracles
# 11               ∞    18.0            600                    Abraxas
# 795              ∞    15.0            600                Life Entity
# 450              ∞    10.0            600               Eru Iluvatar
# 1289             ∞     9.0            600          The Lord Of Light
# 1143            94    28.0            460                Sensei Yang
# 314              9    22.0            425           Commander Machia
#
#                                                   teams              creator  \
# 1281                                                 []                  NaN
# 526                                                  []                  NaN
# 174    ['Secret Six', 'Young Justice', 'Birds of Prey']            DC Comics
# 482                                                  []                  NaN
# 1337                                                 []        Marvel Comics
# 809                                                  []        Marvel Comics
# 1272                                                 []        Marvel Comics
# 882                                    ['The Presence']            DC Comics
# 376                                                  []            DC Comics
# 1202                                                 []            DC Comics
# 153                               ['Gods', 'Beyonders']        Marvel Comics
# 803                                                  []                  NaN
# 1290                                                 []        Marvel Comics
# 845                                                  []         Image Comics
# 11    ['Cosmic Beings', 'Thor Corps', 'Gods of Esgar...        Marvel Comics
# 795                                                  []            DC Comics
# 450                                                  []     J. R. R. Tolkien
# 1289                                                 []  George R. R. Martin
# 1143                                                 []                  NaN
# 314                                                  []                  NaN
#
#       gender
# 1281    Male
# 526     Male
# 174      NaN
# 482     Male
# 1337     NaN
# 809     Male
# 1272    Male
# 882     Male
# 376   Female
# 1202    Male
# 153     Male
# 803     Male
# 1290    Male
# 845   Female
# 11      Male
# 795      NaN
# 450     Male
# 1289     NaN
# 1143    Male
# 314   Female

# %% [markdown]
# `Question 8 - Report on the 10 superheros with most relative

# %%
import re
df_relatives = df[['name','alignment','relatives']]
df_relatives['relatives']=df_relatives['relatives'].fillna(value='')
df_relatives['alignment']=df_relatives['alignment'].fillna(value='None')

def count_distinct_relatives(group): 
    
    #elements= group.strip('[]').replace('\'', '').replace('\n', ';').replace(')', ';').split(';') 
    
    group = re.sub(r'\(.+?\)',';',group)   
    elements= group.strip('.').replace(',', '')
    elements= re.split(';',elements)  
    distinct_teams = pd.Series(elements).unique()
    return (len([elem.strip() for elem in distinct_teams if elem.strip() != '']))



df_relatives['numberofrelatives'] = df_relatives['relatives'].apply(count_distinct_relatives)
df_relatives.sort_values(by='numberofrelatives', ascending=False).head(10)
# Out:
#                             name alignment  \
# 936                        Namor      Good
# 75                       Aquaman      Good
# 574                        Havok      Good
# 1100                     Robin V      Good
# 340                      Cyclops      Good
# 121                   Baron Zemo       Bad
# 515   Ghost Rider (King Of Hell)      Good
# 1251                   Supergirl      Good
# 637                Infernal Hulk       Bad
# 750                  King Thanos       Bad
#
#                                               relatives  numberofrelatives
# 936   Elanna (maternal ancestor), Tanas (maternal an...                 45
# 75    Koryak (son), Arthur Curry, Jr. (son), A.J. (s...                 36
# 574   Oscar Summers (adoptive paternal distant ances...                 30
# 1100  Talia al Ghul (mother),\nBruce Wayne (Batman, ...                 21
# 340   Oscar Summers (adoptive paternal distant ances...                 21
# 121   Harbin Zemo (distant ancestor, deceased);\nHad...                 19
# 515   Illyana Kale (maternal ancestor, deceased); De...                 18
# 1251  Zor-El (father), Allura In-Ze (mother), Jor-El...                 17
# 637   Bruce Banner I (paternal grandfather, presumed...                 17
# 750   A'Lars (father, deceased);\nSui-San (mother, d...                 16

# %% [markdown]
# `Question - Find the top 5 superpowers in descending order

# %%
df=pd.read_csv('superheroes_nlp_dataset.csv')
df['superpowers']
def string_to_list(string):
    # Remove square brackets and quotes, split by comma, and strip whitespace
    elements= string.strip('[]').replace('\'', '').split(',')
    return [elem.strip() for elem in elements]

df['superpowers'] = df['superpowers'].apply(lambda x: list(string_to_list(x)))
from collections import Counter


# Flatten the arrays into a single list
flat_list = [item for sublist in df['superpowers'] for item in sublist]

# Count the distinct superpower in the flattened list
distinct_superpower_counts = dict(Counter(flat_list))

sorted_items = sorted(distinct_superpower_counts.items(), key=lambda item: item[1], reverse=True)
n_largest_items = sorted_items[:5]

# Display the '5' largest items with their counts
for item, count in n_largest_items:
    print(f"{item}: {count}")
# Out:
# Agility: 778
# Stamina: 737
# Super Strength: 731
# Durability: 708
# Intelligence: 599

# %% [markdown]
# `Question 3 - Which Race has the most immortal Superheros

# %%
df_teams= df[['name','teams','creator','has_immortality','alignment','type_race']]

df_immortality = df_teams[df_teams['has_immortality'] > 0.00]
df_immortality.groupby('type_race')['type_race'].count().sort_values(ascending=False).head(5)
# Out:
# type_race
# God / Eternal    36
# Human            29
# Demon            18
# New God          11
# Cosmic Entity     8
# Name: type_race, dtype: int64

# %% [markdown]
# `Question 4 - Name the creator having most superheros of type Paradenom

# %%
creator_counts = df[df['type_race'] == 'Parademon']['creator'].value_counts()

# Find the creator with the most superheroes of type 'Paradenom'
creator_with_most_paradenom = creator_counts.idxmax()

print("The creator with the most superheroes of type 'Paradenom' is:", creator_with_most_paradenom)
creator_counts
# Out:
# The creator with the most superheroes of type 'Paradenom' is: DC Comics
# DC Comics    1
# Name: creator, dtype: int64

# %% [markdown]
# `Question 5 Which comic creator has the most super hero teams

# %%
df_creator = df.groupby('creator')['teams'].count()
#df_creator

def string_to_list(string):
    # Remove square brackets and quotes, split by comma, and strip whitespace
    elements= string.strip('[]').replace('\'', '').split(',')
    #print(elements)
    return [elem.strip() for elem in elements if elem.strip() != '']



def count_distinct_teams_with_names(group):
    group = group.apply(lambda x: list(string_to_list(x)))
    
    flat_list = [item for sublist in group for item in sublist]
    #print(flat_list)
    distinct_teams = pd.Series(flat_list).unique()    

    return (len(distinct_teams))



distinct_teamsbycreator = df.groupby('creator')['teams'].apply(count_distinct_teams_with_names)

df_teams= df.groupby('creator')['teams'].apply(count_distinct_teams_with_names).reset_index()

# %%
df_teams.sort_values(by='teams', ascending=False).head(1).reset_index()
# Out:
#    index        creator  teams
# 0     22  Marvel Comics    165

# %%
def string_to_list(string):
    # Remove square brackets and quotes, split by comma, and strip whitespace
    elements= string.strip('[]').replace('\'', '').split(',')
    #print(elements)
    return [elem.strip() for elem in elements if elem.strip() != '']



def count_distinct_teams_with_names(group):
    group = group.apply(lambda x: list(string_to_list(x)))
    
    flat_list = [item for sublist in group for item in sublist]
    #print(flat_list)
    distinct_teams = pd.Series(flat_list).unique()    

    return (len(distinct_teams))


df['teamcount']=df['teams'].apply(count_distinct_teams_with_names)

df[['overall_score']+['powers']+['combine_score']+demo_cols].sort_values(by=['overall_score','powers','combine_score'], ascending=False).head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 19
#      14     distinct_teams = pd.Series(flat_list).unique()
#      16     return (len(distinct_teams))
# ---> 19 df['teamcount']=df['teams'].apply(count_distinct_teams_with_names)
#      21 df[['overall_score']+['powers']+['combine_score']+demo_cols].sort_values(by=['overall_score','powers','combine_score'], ascending=False).head(20)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[139], line 10, in count_distinct_teams_with_names(group)
#       9 def count_distinct_teams_with_names(group):
# ---> 10     group = group.apply(lambda x: list(string_to_list(x)))
#      12     flat_list = [item for sublist in group for item in sublist]
#      13     #print(flat_list)
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
type(df['teams'][0])
# Out:
# list
